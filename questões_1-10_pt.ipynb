# %% [markdown]
# 1. Qual das opções a seguir define corretamente uma sintaxe em Python?
#
# uma. É um conjunto de regras sobre como um código Python será escrito e interpretado
# b. É um conjunto de comandos encontrados em Python
# c. É um conjunto de funções e classes embutidas na programação Python
# d. Todas as palavras reservadas encontradas em Python
#
# 2. Qual das seguintes opções descreve corretamente uma variável?
#
# uma. Um local de memória reservado para um objeto
# b. Um número em Python
# c. Uma string e um número em Python
# d. Uma string em Python
#
# 3. Você não pode iniciar uma variável Python com uma letra maiúscula. Verdadeiro ou falso
#
# uma. Verdadeiro
# b. Falso
#
# 4. Mary escreve o seguinte código:
# ´código´meunome = "Maria"´código´
# Do código acima, qual é uma variável?
#
# uma. Mary
# b. meu nome e “Maria
# c. o meu nome
# d. Nenhuma das acima
#
# 5. John está tentando criar um nome de variável para um valor chamado orange. Qual dos seguintes códigos retornará um
# erro?
#
# uma. fruta = "laranja"
# b. Fruta = "Laranja"
# c. _fruta = "laranja"
# d. -fruta- = "Laranja"
#
# 6. Em Python, a indentação é apenas para facilitar a leitura. Não tem nenhum impacto em como o código é interpretado. Verdadeiro ou falso?
#
# uma. Verdadeiro
# b. Falso
#
# 7. Veja o código abaixo:
# código
# x = 2
# imprimir(x)
# código
# Quando esse código for executado, ele gerará um erro. Verdadeiro ou falso?
#
# uma. Verdadeiro
# b. Falso
#
# 8. Qual dos seguintes é um nome impróprio para uma variável em Python?
#
# uma. Sete
# b. número sete
# c. Número sete
# d. número sete
#
# 9. Mike escreve o seguinte código:
# 9Meunome = "Mike"
# Mike executa o código e gera um erro de sintaxe. O que há de errado com o código?
#
# uma. O nome Mike não deve estar entre aspas
# b. O nome Mike não deve começar com letra maiúscula
# c. O nome da variável não deve começar com um número
# d. Meu nome não deve ser escrito como uma palavra
#
# 10. Peter quer criar uma string, então escreve o seguinte código:
# meunome = Pedro
# print(meunome)
# Peter tenta executar o código, mas gera um erro. O que há de errado com o código?
#
# uma. O nome da variável deve começar com uma letra minúscula
# b. O nome Pedro deve começar com uma letra minúscula
# c. O nome Pedro deve
# d. Todos acima
